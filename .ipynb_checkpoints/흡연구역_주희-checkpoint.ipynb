# %% [markdown]
# ```
# 용산구 행 : 71개
# 중구 행: 6개
# 관악구 행 : 11개
# 성북구 행 : 14개
# 은평구 행: 262개
# 구로구 행: 19개, 총 : 37개
# 강동구
# 서초구 행 : 58개
# 금천구
# ```

# %% [markdown]
# ### 변수: 지역(행정구), 건물/상호명(건물명이 없으면 상호명), 흡연시설형태(개방형/폐쇄형으로만 나누기), 세부 주소, 위도, 경도

# %% [markdown]
#     p1 = re.compile ('([\w]+[로]) ([\w]+[길] [\d]+)')       # ~로~길이 붙어있음;;;;
#     p2 = re.compile ('([\w]+[로]) ([\w]+[길] [\d]+[-][\d]+)')
#     p3 = re.compile ('([\w]+[로])([\w]+[길] [\d]+)')
#     p4 = re.compile ('([\w]+[로])([\w]+[길] [\d]+[-][\d]+)')
#     p5 = re.compile ('[\w]+[로] [\d]+[-][\d]+')
#     p6 = re.compile ('[\w]+[길] [\d]+[-][\d]+')
#     p7 = re.compile ('[\w]+[로] [\d]+')
#     p8 = re.compile ('[\w]+[길] [\d]+')
#     p9 = re.compile ('[\w]+[로][\d]+[-][\d]+')
#     p10 = re.compile ('[\w]+[길][\d]+[-][\d]+')
#     p11 = re.compile ('[\w]+[로][\d]+')
#     p12 = re.compile ('[\w]+[길][\d]+')

# %% [markdown]
# # 용산구

# %%
import pandas as pd

yongsan= pd.read_csv('흡연구역_주희/서울특별시 용산구_흡연구역_10_22_2021.csv', encoding='cp949')
yongsan
# Out:
#    자치구명              시설 구분 시설형태          서울특별시 용산구 설치 위치    설치 주체         위도  \
# 0   용산구                철도역  개방형   서울특별시 용산구 서울역 광장 15번출구   한국철도공사  37.553149
# 1   용산구                철도역  개방형    서울특별시 용산구 서울역 광장 1번출구   한국철도공사  37.553760
# 2   용산구            철도역(조례)  개방형         서울특별시 용산구 용산역 광장  현대아이파크몰  37.528404
# 3   용산구                 청사  개방형        서울특별시 용산구 용산구청 옥상     용산구청  37.532709
# 4   용산구                 청사  개방형     서울특별시 용산구 용산구청 2층 외부     용산구청  37.532709
# ..  ...                ...  ...                      ...      ...        ...
# 66  용산구  연면적 1000㎡ 이상 대형건물  폐쇄형     서울특별시 용산구 LS용산타워 주차장    ㈜하나은행  37.528002
# 67  용산구                대학교  개방형  서울특별시 용산구 한국폴리텍대학 정수캠퍼스  한국폴리텍대학  37.529136
# 68  용산구                대학교  개방형  서울특별시 용산구 한국폴리텍대학 정수캠퍼스  한국폴리텍대학  37.528710
# 69  용산구                대학교  개방형  서울특별시 용산구 한국폴리텍대학 정수캠퍼스  한국폴리텍대학  37.529323
# 70  용산구                대학교  개방형  서울특별시 용산구 한국폴리텍대학 정수캠퍼스  한국폴리텍대학  37.529799
#
#             경도
# 0   126.968881
# 1   126.969662
# 2   126.965569
# 3   126.990000
# 4   126.990000
# ..         ...
# 66  126.967632
# 67  126.996483
# 68  126.996226
# 69  126.995976
# 70  126.996498
#
# [71 rows x 7 columns]

# %%
yongsan.drop(['시설 구분'], axis = 1, inplace = True)

# %%
yongsan.rename(columns = {'자치구명' : '지역(행정구)', '시설형태':'흡연시설형태', '설치 주체':'건물/상호명', '서울특별시 용산구 설치 위치':'세부 주소'}, inplace = True)

# %%
yongsan.columns
# Out:
# Index(['지역(행정구)', '흡연시설형태', '세부 주소', '건물/상호명', '위도', '경도'], dtype='object')

# %%
yongsan = yongsan[['지역(행정구)','건물/상호명', '흡연시설형태', '세부 주소', '위도', '경도']]
yongsan
# Out:
#    지역(행정구)   건물/상호명 흡연시설형태                    세부 주소         위도          경도
# 0      용산구   한국철도공사    개방형   서울특별시 용산구 서울역 광장 15번출구  37.553149  126.968881
# 1      용산구   한국철도공사    개방형    서울특별시 용산구 서울역 광장 1번출구  37.553760  126.969662
# 2      용산구  현대아이파크몰    개방형         서울특별시 용산구 용산역 광장  37.528404  126.965569
# 3      용산구     용산구청    개방형        서울특별시 용산구 용산구청 옥상  37.532709  126.990000
# 4      용산구     용산구청    개방형     서울특별시 용산구 용산구청 2층 외부  37.532709  126.990000
# ..     ...      ...    ...                      ...        ...         ...
# 66     용산구    ㈜하나은행    폐쇄형     서울특별시 용산구 LS용산타워 주차장  37.528002  126.967632
# 67     용산구  한국폴리텍대학    개방형  서울특별시 용산구 한국폴리텍대학 정수캠퍼스  37.529136  126.996483
# 68     용산구  한국폴리텍대학    개방형  서울특별시 용산구 한국폴리텍대학 정수캠퍼스  37.528710  126.996226
# 69     용산구  한국폴리텍대학    개방형  서울특별시 용산구 한국폴리텍대학 정수캠퍼스  37.529323  126.995976
# 70     용산구  한국폴리텍대학    개방형  서울특별시 용산구 한국폴리텍대학 정수캠퍼스  37.529799  126.996498
#
# [71 rows x 6 columns]

# %%
import re
idx = 0

for i in yongsan['건물/상호명']:
    i = re.sub('\W','',i)
    yongsan.loc[idx, '건물/상호명'] = i
    idx += 1
yongsan
# Out:
#    지역(행정구)   건물/상호명 흡연시설형태                    세부 주소         위도          경도
# 0      용산구   한국철도공사    개방형   서울특별시 용산구 서울역 광장 15번출구  37.553149  126.968881
# 1      용산구   한국철도공사    개방형    서울특별시 용산구 서울역 광장 1번출구  37.553760  126.969662
# 2      용산구  현대아이파크몰    개방형         서울특별시 용산구 용산역 광장  37.528404  126.965569
# 3      용산구     용산구청    개방형        서울특별시 용산구 용산구청 옥상  37.532709  126.990000
# 4      용산구     용산구청    개방형     서울특별시 용산구 용산구청 2층 외부  37.532709  126.990000
# ..     ...      ...    ...                      ...        ...         ...
# 66     용산구     하나은행    폐쇄형     서울특별시 용산구 LS용산타워 주차장  37.528002  126.967632
# 67     용산구  한국폴리텍대학    개방형  서울특별시 용산구 한국폴리텍대학 정수캠퍼스  37.529136  126.996483
# 68     용산구  한국폴리텍대학    개방형  서울특별시 용산구 한국폴리텍대학 정수캠퍼스  37.528710  126.996226
# 69     용산구  한국폴리텍대학    개방형  서울특별시 용산구 한국폴리텍대학 정수캠퍼스  37.529323  126.995976
# 70     용산구  한국폴리텍대학    개방형  서울특별시 용산구 한국폴리텍대학 정수캠퍼스  37.529799  126.996498
#
# [71 rows x 6 columns]

# %%
pip install folium
# Out:
# Requirement already satisfied: folium in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (0.12.1.post1)Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from folium) (1.22.3)
# Requirement already satisfied: jinja2>=2.9 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from folium) (3.0.1)
# Requirement already satisfied: requests in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from folium) (2.27.1)
# Requirement already satisfied: branca>=0.3.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from folium) (0.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from jinja2>=2.9->folium) (2.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from requests->folium) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from requests->folium) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from requests->folium) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from requests->folium) (1.26.9)

# %%
import folium

m = folium.Map(location=[37.553149, 126.968881], zoom_start = 22)

folium.Marker([37.553149, 126.968881],tooltip='<i>한국철도공사</i>').add_to(m) # tooltip: 마우스오버시 상세내용 표시
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0516e6b0a9552bfe1957b292019750a9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0516e6b0a9552bfe1957b292019750a9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_0516e6b0a9552bfe1957b292019750a9 = L.map(
#                 &quot;map_0516e6b0a9552bfe1957b292019750a9&quot;,
#                 {
#                     center: [37.553149, 126.968881],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 22,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a6ef0b4fe30ecb469a3602d0ac017e57 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0516e6b0a9552bfe1957b292019750a9);
#
#
#             var marker_6428294db06ea6806fe5a19aacd11eb9 = L.marker(
#                 [37.553149, 126.968881],
#                 {}
#             ).addTo(map_0516e6b0a9552bfe1957b292019750a9);
#
#
#             marker_6428294db06ea6806fe5a19aacd11eb9.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;i&gt;한국철도공사&lt;/i&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 은평구

# %%
import pandas as pd

eunpyeong= pd.read_csv('흡연구역_주희/서울특별시_은평구_흡연실현황_20220101.csv', encoding='cp949')
eunpyeong
# Out:
#        업종 흡연시설구분 흡연시설형태       상호명    시도명 시군구명  \
# 0    게임시설     실내    폐쇄형    은평게임랜드  서울특별시  은평구
# 1    게임시설     실내    폐쇄형    삼성게임랜드  서울특별시  은평구
# 2    게임시설     실내    폐쇄형    명정게임랜드  서울특별시  은평구
# 3    게임시설     실내    폐쇄형  연신내 게임랜드  서울특별시  은평구
# 4    게임시설     실내    폐쇄형      인터라켄  서울특별시  은평구
# ..    ...    ...    ...       ...    ...  ...
# 257    청사     실외    폐쇄형  은평구청 주차장  서울특별시  은평구
# 258    청사     실외    개방형     은평소방서  서울특별시  은평구
# 259   도서관     실외    개방형   증산정보도서관  서울특별시  은평구
# 260   음식점     실외    개방형    포션 씨푸드  서울특별시  은평구
# 261   음식점     실외    폐쇄형     송추가마골  서울특별시  은평구
#
#                             소재지도로명주소     데이터기준일자
# 0                     연서로29길 5 (갈현동)  2022-01-01
# 1                  통일로 720, 3층 (불광동)  2022-01-01
# 2    통일로 855-8, 연신내진원와이타운 지하1층 (갈현동)  2022-01-01
# 3          연서로29길 8-8, 인락빌딩 3층 (갈현동)  2022-01-01
# 4              진관2로 29-21 (진관동,지하1층)  2022-01-01
# ..                               ...         ...
# 257                     은평로 195(녹번동)  2022-01-01
# 258                     통일로 962(진관동)  2022-01-01
# 259                     증산로5길 6(증산동)  2022-01-01
# 260                     불광로 20 (대조동)  2022-01-01
# 261                북한산로 276 예강1(진관동)  2022-01-01
#
# [262 rows x 8 columns]

# %%
#소재지도로명주소 전처리
import re 
idx = 0
for i in list(eunpyeong['소재지도로명주소']):
    p1 = re.compile ('([\w]+[로])([\w]+[길] [\d]+)') 
    p2 = re.compile ('([\w]+[로])([\w]+[길] [\d]+[-][\d]+)')
    p3 = re.compile ('[\w]+[로] [\d]+[-][\d]+')
    p4 = re.compile ('[\w]+[길] [\d]+[-][\d]+')
    p5 = re.compile ('[\w]+[로] [\d]+')
    p6 = re.compile ('[\w]+[길] [\d]+')
    
    try:
        re1 = re.search(p1, str(eunpyeong.loc[idx, '소재지도로명주소'])).group()
#         re1 = re1.group(1)+re1.group(2)
    except:
        try: 
            re1 = re.search(p2, str(eunpyeong.loc[idx, '소재지도로명주소'])).group()
#             re1 = re1.group(1)+re1.group(2)
        except:
            try:
                re1 = re.search(p3, str(eunpyeong.loc[idx, '소재지도로명주소'])).group()
            except:
                try:
                    re1 = re.search(p4, str(eunpyeong.loc[idx, '소재지도로명주소'])).group()
                except:
                    try:
                        re1 = re.search(p5, str(eunpyeong.loc[idx, '소재지도로명주소'])).group()
                    except:
                        try:
                            re1 = re.search(p6, str(eunpyeong.loc[idx, '소재지도로명주소'])).group()
                        except:
                            pass

    
    eunpyeong.loc[idx, '소재지도로명주소_clean'] = re1
    idx += 1
    
# eunpyeong[eunpyeong['소재지도로명주소_clean'].isnull()]
eunpyeong['소재지도로명주소_clean'].unique()
# Out:
# array(['연서로29길 5', '통일로 720', '통일로 855-8', '연서로29길 8', '진관2로 29-21',
#        '연서로 73', '통일로 731', '연서로32길 3', '응암로 168-1', '갈현로41길 10',
#        '은평로 192', '통일로 855-20', '통일로83길 6', '은평로 187-1', '갈현로 39-1',
#        '서오릉로 178', '통일로 850', '진흥로 112', '은평로 5', '통일로 697', '서오릉로 192',
#        '갈현로 188', '서오릉로 77', '연서로 213', '통일로 827', '진흥로 144', '연서로 247',
#        '진관2로 15-46', '진흥로 148', '갈현로 14', '은평로 6', '진흥로1길 34', '은평로 56',
#        '응암로22길 22', '갈현로 82', '통일로 835', '응암로13길 14', '연서로17길 34',
#        '갈현로 181-24', '통일로 856', '불광로 90', '증산로21길 11', '진흥로1길 24',
#        '갈현로 100', '갈현로 81', '은평로 108', '불광천길 536', '가좌로7길 11',
#        '응암로 340-1', '은평로 136', '통일로 1030', '통일로 834', '통일로 760', '갈현로 7',
#        '통일로 1050', '응암로11길 15', '통일로 854', '서오릉로 72', '통일로 728-1',
#        '은평로 111', '연서로 249', '불광로 27', '갈현로 9', '연서로 205', '통일로 715-12',
#        '통일로 727', '연서로27길 7', '불광로 46', '통일로83길 5', '은평로 51-1', '은평로 17',
#        '서오릉로 9-13', '연서로29길 16', '연서로 317', '통일로65길 12', '진흥로 121-7',
#        '통일로 1022', '서오릉로 200', '통일로 863-8', '통일로 738', '서오릉로 204',
#        '연서로27길 16', '응암로 187', '통일로 842', '불광로 20', '응암로 339', '통일로 684',
#        '은평로 195', '은평로10길 2', '은평로 65', '통일로 855-4', '연서로 135', '은평로 102',
#        '통일로 838-4', '통일로 724-1', '연서로29길 7', '은평로 64', '증산로21길 12',
#        '은평로 43', '응암로 302', '은평로8길 8', '응암로 248', '응암로 204', '불광천길 390-2',
#        '응암로 190', '은평로 45-1', '응암로13길 22', '통일로 855-14', '응암로 302-1',
#        '연서로26길 9', '은평로11길 11', '연서로 209', '서오릉로 151', '진흥로1길 28',
#        '진흥로 134', '서오릉로 82', '통일로78길 7', '진관3로 37', '백련산로4길 16',
#        '서오릉로 94', '통일로 677', '연서로17길 13', '연서로29길 14', '서오릉로 208',
#        '연서로29길 13', '은평로 173', '통일로66길 2', '가좌로 318', '은평로 37',
#        '가좌로5길 22', '서오릉로 195', '응암로 292', '응암로 247', '은평로 193-2',
#        '은평로 34', '응암로13길 5', '연서로 211', '응암로 180', '응암로 252', '통일로 739',
#        '증산로 307', '서오릉로 140', '갈현로 77', '통일로87길 21', '연서로 214',
#        '통일로87길 5', '증산서길 107', '역말로 101', '은평로 145', '응암로11길 3',
#        '서오릉로 58', '은평로 91', '통일로 751', '연서로 292', '증산로 361', '은평로 229',
#        '불광천길 326', '증산로9길 12', '응암로 178-1', '대서문길 9', '연서로27길 15',
#        '증산서길 153', '통일로 723', '연서로29길 20', '연서로4길 6', '응암로 213', '역서로 91',
#        '연서로27길 8', '연서로 154', '불광로 10', '진흥로 29', '연서로 262', '증산서길 98',
#        '응암로 200', '갈현로 54-8', '응암로 161', '역말로 6', '진흥로 105-6', '통일로 937',
#        '통일로 822', '연서로 71', '증산서길 154', '가좌로 321', '연서로 58', '연서로 295',
#        '은평로 52', '응암로22길 20', '갈현로 186', '갈현로16길 17', '진관3로 22',
#        '응암로 269', '갈현로36길 18', '진흥로 235', '통일로 71', '불광로 121',
#        '연서로48길 41', '갈현로11길 30', '은평로8길 1', '백련산로 90', '연서로 365',
#        '통일로 962', '증산로5길 6', '북한산로 276'], dtype=object)

# %%
eunpyeong.columns
# Out:
# Index(['업종', '흡연시설구분', '흡연시설형태', '상호명', '시도명', '시군구명', '소재지도로명주소', '데이터기준일자',
#        '소재지도로명주소_clean'],
#       dtype='object')

# %%
#뒤에서 drop 한 번에 하려고 '세부 주소'칼럼 먼저 형성 

eunpyeong["세부 주소"] = eunpyeong["시도명"] + " " + eunpyeong["시군구명"] + ' ' + eunpyeong['소재지도로명주소']
eunpyeong
# Out:
#        업종 흡연시설구분 흡연시설형태       상호명    시도명 시군구명  \
# 0    게임시설     실내    폐쇄형    은평게임랜드  서울특별시  은평구
# 1    게임시설     실내    폐쇄형    삼성게임랜드  서울특별시  은평구
# 2    게임시설     실내    폐쇄형    명정게임랜드  서울특별시  은평구
# 3    게임시설     실내    폐쇄형  연신내 게임랜드  서울특별시  은평구
# 4    게임시설     실내    폐쇄형      인터라켄  서울특별시  은평구
# ..    ...    ...    ...       ...    ...  ...
# 257    청사     실외    폐쇄형  은평구청 주차장  서울특별시  은평구
# 258    청사     실외    개방형     은평소방서  서울특별시  은평구
# 259   도서관     실외    개방형   증산정보도서관  서울특별시  은평구
# 260   음식점     실외    개방형    포션 씨푸드  서울특별시  은평구
# 261   음식점     실외    폐쇄형     송추가마골  서울특별시  은평구
#
#                             소재지도로명주소     데이터기준일자 소재지도로명주소_clean  \
# 0                     연서로29길 5 (갈현동)  2022-01-01       연서로29길 5
# 1                  통일로 720, 3층 (불광동)  2022-01-01        통일로 720
# 2    통일로 855-8, 연신내진원와이타운 지하1층 (갈현동)  2022-01-01      통일로 855-8
# 3          연서로29길 8-8, 인락빌딩 3층 (갈현동)  2022-01-01       연서로29길 8
# 4              진관2로 29-21 (진관동,지하1층)  2022-01-01     진관2로 29-21
# ..                               ...         ...            ...
# 257                     은평로 195(녹번동)  2022-01-01        은평로 195
# 258                     통일로 962(진관동)  2022-01-01        통일로 962
# 259                     증산로5길 6(증산동)  2022-01-01        증산로5길 6
# 260                     불광로 20 (대조동)  2022-01-01         불광로 20
# 261                북한산로 276 예강1(진관동)  2022-01-01       북한산로 276
#
#                                          세부 주소
# 0                     서울특별시 은평구 연서로29길 5 (갈현동)
# 1                  서울특별시 은평구 통일로 720, 3층 (불광동)
# 2    서울특별시 은평구 통일로 855-8, 연신내진원와이타운 지하1층 (갈현동)
# 3          서울특별시 은평구 연서로29길 8-8, 인락빌딩 3층 (갈현동)
# 4              서울특별시 은평구 진관2로 29-21 (진관동,지하1층)
# ..                                         ...
# 257                     서울특별시 은평구 은평로 195(녹번동)
# 258                     서울특별시 은평구 통일로 962(진관동)
# 259                     서울특별시 은평구 증산로5길 6(증산동)
# 260                     서울특별시 은평구 불광로 20 (대조동)
# 261                서울특별시 은평구 북한산로 276 예강1(진관동)
#
# [262 rows x 10 columns]

# %%
eunpyeong.drop(['업종', '흡연시설구분', '시도명','소재지도로명주소', '데이터기준일자'], axis = 1, inplace = True)
eunpyeong
# Out:
#     흡연시설형태       상호명 시군구명 소재지도로명주소_clean  \
# 0      폐쇄형    은평게임랜드  은평구       연서로29길 5
# 1      폐쇄형    삼성게임랜드  은평구        통일로 720
# 2      폐쇄형    명정게임랜드  은평구      통일로 855-8
# 3      폐쇄형  연신내 게임랜드  은평구       연서로29길 8
# 4      폐쇄형      인터라켄  은평구     진관2로 29-21
# ..     ...       ...  ...            ...
# 257    폐쇄형  은평구청 주차장  은평구        은평로 195
# 258    개방형     은평소방서  은평구        통일로 962
# 259    개방형   증산정보도서관  은평구        증산로5길 6
# 260    개방형    포션 씨푸드  은평구         불광로 20
# 261    폐쇄형     송추가마골  은평구       북한산로 276
#
#                                          세부 주소
# 0                     서울특별시 은평구 연서로29길 5 (갈현동)
# 1                  서울특별시 은평구 통일로 720, 3층 (불광동)
# 2    서울특별시 은평구 통일로 855-8, 연신내진원와이타운 지하1층 (갈현동)
# 3          서울특별시 은평구 연서로29길 8-8, 인락빌딩 3층 (갈현동)
# 4              서울특별시 은평구 진관2로 29-21 (진관동,지하1층)
# ..                                         ...
# 257                     서울특별시 은평구 은평로 195(녹번동)
# 258                     서울특별시 은평구 통일로 962(진관동)
# 259                     서울특별시 은평구 증산로5길 6(증산동)
# 260                     서울특별시 은평구 불광로 20 (대조동)
# 261                서울특별시 은평구 북한산로 276 예강1(진관동)
#
# [262 rows x 5 columns]

# %%
#위도 경도를 추출해주는 사용자 정의 함수 만들기

from geopy.geocoders import Nominatim
geo_local = Nominatim(user_agent='South Korea')

def geocoding(address):
    geo = geo_local.geocode(address)
    x = geo.latitude 
    y = geo.longitude
    return x, y

# %%
#위도, 경도 컬럼 만들어주기

idx =0
for i in eunpyeong['소재지도로명주소_clean']:
    try:
        eunpyeong.loc[idx,'위도'] = geocoding(i)[0]
        eunpyeong.loc[idx,'경도'] = geocoding(i)[1]
    except:
        pass
    idx += 1
eunpyeong
# Out:
#     흡연시설형태       상호명 시군구명 소재지도로명주소_clean  \
# 0      폐쇄형    은평게임랜드  은평구       연서로29길 5
# 1      폐쇄형    삼성게임랜드  은평구        통일로 720
# 2      폐쇄형    명정게임랜드  은평구      통일로 855-8
# 3      폐쇄형  연신내 게임랜드  은평구       연서로29길 8
# 4      폐쇄형      인터라켄  은평구     진관2로 29-21
# ..     ...       ...  ...            ...
# 257    폐쇄형  은평구청 주차장  은평구        은평로 195
# 258    개방형     은평소방서  은평구        통일로 962
# 259    개방형   증산정보도서관  은평구        증산로5길 6
# 260    개방형    포션 씨푸드  은평구         불광로 20
# 261    폐쇄형     송추가마골  은평구       북한산로 276
#
#                                          세부 주소         위도          경도
# 0                     서울특별시 은평구 연서로29길 5 (갈현동)  37.618761  126.918830
# 1                  서울특별시 은평구 통일로 720, 3층 (불광동)  37.585780  126.947400
# 2    서울특별시 은평구 통일로 855-8, 연신내진원와이타운 지하1층 (갈현동)  37.585780  126.947400
# 3          서울특별시 은평구 연서로29길 8-8, 인락빌딩 3층 (갈현동)  37.618761  126.918830
# 4              서울특별시 은평구 진관2로 29-21 (진관동,지하1층)  37.635669  126.919233
# ..                                         ...        ...         ...
# 257                     서울특별시 은평구 은평로 195(녹번동)  37.597487  126.909943
# 258                     서울특별시 은평구 통일로 962(진관동)  37.628672  126.919797
# 259                     서울특별시 은평구 증산로5길 6(증산동)  37.582823  126.907650
# 260                     서울특별시 은평구 불광로 20 (대조동)  37.609703  126.928909
# 261                서울특별시 은평구 북한산로 276 예강1(진관동)  37.668554  126.951278
#
# [262 rows x 7 columns]

# %%
eunpyeong.rename(columns = {'시군구명' : '지역(행정구)', '상호명':'건물/상호명'}, inplace = True)

# %%
eunpyeong.columns

# %%
#세부 주소 전처리해서 위도, 경도 칼럼 만들어야해서 세부 주소 칼럼 하나 더 생성 
eunpyeong = eunpyeong[['지역(행정구)','건물/상호명', '흡연시설형태', '세부 주소', '세부 주소']]

# %%
#세부 주소에서 (-동) 지우기 

idx = 0

for i in eunpyeong['세부 주소']:
    i = re.sub('\(.*\)','',i)
    eunpyeong.loc[idx, '세부 주소'] = i
    idx += 1
eunpyeong

# %%
#위도, 경도 추가 
# !pip install geopy

# %%
#위도 경도를 추출해주는 사용자 정의 함수 만들기

from geopy.geocoders import Nominatim
geo_local = Nominatim(user_agent='South Korea')

def geocoding(address):
    geo = geo_local.geocode(address)
    x = geo.latitude 
    y = geo.longitude
    return x, y
geocoding('연서로29길 8-8')

# %%
#위도, 경도 컬럼 만들어주기

idx =0
for i in eunpyeong['세부 주소']:
    try:
        gangseo.loc[idx,'위도'] = geocoding(i)[0]
        gangseo.loc[idx,'경도'] = geocoding(i)[1]
    except:
        pass
    idx += 1
gangseo
